# %% [markdown]
# # Prepare dataset (jsonl file)

# %% [markdown]
# - Prepare PE datasets for llama factory.
#
# - Stance classification

# %% [markdown]
# ## Libraries

# %%
import os
import ast
import json
import random
import pickle
import pandas as pd

# %%
random.seed(42)

# %% [markdown]
# ## Load Data

# %%
data_dir = os.path.join(os.getcwd(), "datasets")

# %%
pe_df = pd.read_csv(os.path.join(data_dir, "PE_data.csv"))

# %%
# pe_df.isna().sum()

# %%
# pe_df

# %% [markdown]
# ### Load train-test-split CSV

# %%
df_split = pd.read_csv("datasets/train-test-split.csv", sep=";")

# %%
df_split.head(10)
# Out:
#          ID    SET
# 0  essay001  TRAIN
# 1  essay002  TRAIN
# 2  essay003  TRAIN
# 3  essay004   TEST
# 4  essay005   TEST
# 5  essay006   TEST
# 6  essay007  TRAIN
# 7  essay008  TRAIN
# 8  essay009  TRAIN
# 9  essay010  TRAIN

# %%
pe_df['split'] = pe_df['essay_id'].map(df_split['SET'])

# %%
pe_df.head(50)
# Out:
#     essay_id  para_id  para_types  \
# 0          0        0      prompt
# 1          0        1       intro
# 2          0        2        body
# 3          0        3        body
# 4          0        4  conclusion
# 5          1        5      prompt
# 6          1        6       intro
# 7          1        7        body
# 8          1        8        body
# 9          1        9  conclusion
# 10         2       10      prompt
# 11         2       11       intro
# 12         2       12        body
# 13         2       13        body
# 14         2       14  conclusion
# 15         3       15      prompt
# 16         3       16       intro
# 17         3       17        body
# 18         3       18        body
# 19         3       19        body
# 20         3       20  conclusion
# 21         4       21      prompt
# 22         4       22       intro
# 23         4       23        body
# 24         4       24        body
# 25         4       25  conclusion
# 26         5       26      prompt
# 27         5       27       intro
# 28         5       28        body
# 29         5       29        body
# 30         5       30  conclusion
# 31         6       31      prompt
# 32         6       32       intro
# 33         6       33        body
# 34         6       34        body
# 35         6       35  conclusion
# 36         7       36      prompt
# 37         7       37       intro
# 38         7       38        body
# 39         7       39        body
# 40         7       40        body
# 41         7       41  conclusion
# 42         8       42      prompt
# 43         8       43       intro
# 44         8       44        body
# 45         8       45        body
# 46         8       46  conclusion
# 47         9       47      prompt
# 48         9       48       intro
# 49         9       49        body
#
#                                             para_text  \
# 0   <prompt> Should students be taught to compete ...
# 1   <para-intro> It is always said that competitio...
# 2   <para-body> First of all , <AC> through cooper...
# 3   <para-body> On the other hand , <AC> the signi...
# 4   <para-conclusion> Consequently , no matter fro...
# 5   <prompt> More people are migrating to other co...
# 6   <para-intro> The last 50 years have seen an in...
# 7   <para-body> Firstly , <AC> maintaining one ’ s...
# 8   <para-body> Secondly , <AC> it is crucial to k...
# 9   <para-conclusion> To conclude , although <AC> ...
# 10  <prompt> International tourism is now more com...
# 11  <para-intro> The last decade has seen an incre...
# 12  <para-body> Firstly , <AC> international touri...
# 13  <para-body> Secondly , <AC> through tourism in...
# 14  <para-conclusion> To conclude , as far as I am...
# 15  <prompt> Will newspapers become a thing of the...
# 16  <para-intro> The internet has been more and mo...
# 17  <para-body> First of all , <AC> to obtain info...
# 18  <para-body> Another point is that , <AC> from ...
# 19  <para-body> Last , but not least , <AC> when t...
# 20  <para-conclusion> In conclusion , it might be ...
# 21  <prompt> Government budget focus , young child...
# 22  <para-intro> " Education is the investment in ...
# 23  <para-body> Concerning that <AC> elementary ed...
# 24  <para-body> That ' s not enough , <AC> for hig...
# 25  <para-conclusion> From reasons listed above , ...
# 26  <prompt> Roommates quality and their importanc...
# 27  <para-intro> Much has been said about the impo...
# 28  <para-body> <AC> Consideration is always impor...
# 29  <para-body> Moreover , <AC> communication is a...
# 30  <para-conclusion> In conclusion , there are ma...
# 31  <prompt> Should governments spend more money o...
# 32  <para-intro> Nowadays transportation has attra...
# 33  <para-body> First and foremost , <AC> carbon e...
# 34  <para-body> In addition , <AC> the policy woul...
# 35  <para-conclusion> In conclusion , I would conc...
# 36               <prompt> Physical exercise </prompt>
# 37  <para-intro> Although some people think that t...
# 38  <para-body> First of all , the ancient Latin p...
# 39  <para-body> Besides , <AC> when we practice ou...
# 40  <para-body> Last , but not least , <AC> financ...
# 41  <para-conclusion> In the conclusion , I would ...
# 42  <prompt> Technology inspires children ' s crea...
# 43  <para-intro> Technology accelerates human ' s ...
# 44  <para-body> First , <AC> technology inspires c...
# 45  <para-body> Second , <AC> technology widen chi...
# 46  <para-conclusion> Admittedly , <AC> technology...
# 47  <prompt> Lessons with teachers versus others s...
# 48  <para-intro> Over the last half century the ch...
# 49  <para-body> Many people find that <AC> student...
#
#                                             adu_spans  \
# 0                                                  []
# 1                                          [(76, 97)]
# 2           [(1, 25), (26, 55), (56, 99), (100, 123)]
# 3   [(1, 22), (24, 37), (39, 63), (76, 139), (155,...
# 4                                           [(1, 40)]
# 5                                                  []
# 6                                          [(54, 77)]
# 7   [(1, 24), (25, 60), (61, 82), (83, 107), (109,...
# 8   [(1, 13), (14, 34), (36, 55), (56, 86), (87, 1...
# 9                                 [(1, 23), (25, 54)]
# 10                                                 []
# 11                                         [(27, 68)]
# 12            [(1, 24), (25, 56), (57, 82), (84, 95)]
# 13           [(1, 20), (22, 61), (62, 83), (85, 100)]
# 14                                          [(1, 29)]
# 15                                                 []
# 16                                         [(44, 76)]
# 17         [(1, 21), (22, 66), (67, 108), (110, 128)]
# 18         [(1, 29), (31, 54), (89, 104), (106, 135)]
# 19                      [(1, 30), (31, 49), (51, 70)]
# 20                                                 []
# 21                                                 []
# 22                                         [(56, 89)]
# 23           [(1, 28), (29, 44), (46, 78), (80, 119)]
# 24  [(1, 34), (35, 63), (64, 79), (80, 87), (88, 1...
# 25                                [(1, 28), (29, 41)]
# 26                                                 []
# 27                               [(45, 60), (62, 77)]
# 28  [(0, 8), (10, 25), (26, 46), (47, 75), (77, 91...
# 29  [(1, 12), (13, 31), (32, 51), (52, 79), (81, 8...
# 30                                         [(14, 30)]
# 31                                                 []
# 32                     [(30, 51), (52, 68), (69, 86)]
# 33  [(1, 16), (18, 40), (41, 65), (66, 91), (93, 1...
# 34  [(1, 16), (17, 34), (36, 55), (57, 80), (81, 1...
# 35                      [(1, 21), (23, 34), (35, 48)]
# 36                                                 []
# 37                                [(1, 32), (33, 58)]
# 38  [(1, 29), (30, 49), (50, 61), (63, 92), (94, 1...
# 39            [(1, 17), (19, 40), (42, 71), (73, 94)]
# 40  [(1, 21), (23, 39), (40, 48), (50, 67), (69, 8...
# 41                                          [(1, 35)]
# 42                                                 []
# 43                              [(75, 90), (91, 102)]
# 44  [(1, 11), (12, 21), (22, 53), (55, 80), (81, 9...
# 45  [(1, 10), (11, 27), (29, 52), (54, 71), (72, 8...
# 46  [(1, 11), (12, 23), (24, 45), (47, 67), (68, 83)]
# 47                                                 []
# 48                                                 []
# 49  [(1, 19), (21, 40), (41, 64), (65, 77), (79, 1...
#
#                                              ac_spans  \
# 0                                                  []
# 1                                          [(86, 97)]
# 2           [(5, 25), (27, 55), (57, 99), (101, 123)]
# 3   [(6, 22), (30, 37), (41, 63), (77, 139), (156,...
# 4                                          [(25, 40)]
# 5                                                  []
# 6                                          [(59, 77)]
# 7   [(3, 24), (26, 60), (62, 82), (84, 107), (115,...
# 8   [(3, 13), (15, 34), (39, 55), (57, 86), (88, 1...
# 9                                 [(5, 23), (32, 54)]
# 10                                                 []
# 11                                         [(48, 68)]
# 12            [(3, 24), (26, 56), (58, 82), (85, 95)]
# 13           [(3, 20), (25, 61), (63, 83), (87, 100)]
# 14                                         [(11, 29)]
# 15                                                 []
# 16                                         [(64, 76)]
# 17         [(5, 21), (23, 66), (68, 108), (112, 128)]
# 18         [(6, 29), (37, 54), (90, 104), (110, 135)]
# 19                      [(7, 30), (32, 49), (55, 70)]
# 20                                                 []
# 21                                                 []
# 22                                         [(77, 89)]
# 23           [(3, 28), (30, 44), (47, 78), (84, 119)]
# 24  [(7, 34), (36, 63), (65, 79), (82, 87), (89, 1...
# 25                               [(14, 28), (30, 41)]
# 26                                                 []
# 27                               [(50, 60), (66, 77)]
# 28  [(1, 8), (13, 25), (27, 46), (48, 75), (79, 91...
# 29  [(3, 12), (14, 31), (33, 51), (53, 79), (83, 8...
# 30                                         [(15, 30)]
# 31                                                 []
# 32                     [(38, 51), (53, 68), (70, 86)]
# 33  [(5, 16), (22, 40), (42, 65), (67, 91), (95, 1...
# 34  [(4, 16), (18, 34), (44, 55), (64, 80), (82, 1...
# 35                      [(8, 21), (25, 34), (36, 48)]
# 36                                                 []
# 37                               [(23, 32), (34, 58)]
# 38  [(21, 29), (31, 49), (51, 61), (65, 92), (96, ...
# 39            [(3, 17), (22, 40), (44, 71), (75, 94)]
# 40  [(7, 21), (26, 39), (42, 48), (54, 67), (75, 8...
# 41                                         [(11, 35)]
# 42                                                 []
# 43                              [(81, 90), (95, 102)]
# 44  [(3, 11), (13, 21), (24, 53), (58, 80), (82, 9...
# 45  [(3, 10), (12, 27), (31, 52), (56, 71), (73, 8...
# 46  [(3, 11), (13, 23), (25, 45), (49, 67), (69, 83)]
# 47                                                 []
# 48                                                 []
# 49  [(5, 19), (24, 40), (42, 64), (66, 77), (84, 1...
#
#                                              ai_spans  \
# 0                                                  []
# 1                                          [(76, 85)]
# 2            [(1, 4), (26, 26), (56, 56), (100, 100)]
# 3   [(1, 5), (24, 29), (39, 40), (76, 76), (155, 1...
# 4                                           [(1, 24)]
# 5                                                  []
# 6                                          [(54, 58)]
# 7   [(1, 2), (25, 25), (61, 61), (83, 83), (109, 1...
# 8   [(1, 2), (14, 14), (36, 38), (56, 56), (87, 87...
# 9                                  [(1, 4), (25, 31)]
# 10                                                 []
# 11                                         [(27, 47)]
# 12             [(1, 2), (25, 25), (57, 57), (84, 84)]
# 13             [(1, 2), (22, 24), (62, 62), (85, 86)]
# 14                                          [(1, 10)]
# 15                                                 []
# 16                                         [(44, 63)]
# 17           [(1, 4), (22, 22), (67, 67), (110, 111)]
# 18           [(1, 5), (31, 36), (89, 89), (106, 109)]
# 19                       [(1, 6), (31, 31), (51, 54)]
# 20                                                 []
# 21                                                 []
# 22                                         [(56, 76)]
# 23             [(1, 2), (29, 29), (46, 46), (80, 83)]
# 24  [(1, 6), (35, 35), (64, 64), (80, 81), (88, 88...
# 25                                [(1, 13), (29, 29)]
# 26                                                 []
# 27                               [(45, 49), (62, 65)]
# 28  [(0, 0), (10, 12), (26, 26), (47, 47), (77, 78...
# 29  [(1, 2), (13, 13), (32, 32), (52, 52), (81, 82...
# 30                                         [(14, 14)]
# 31                                                 []
# 32                     [(30, 37), (52, 52), (69, 69)]
# 33  [(1, 4), (18, 21), (41, 41), (66, 66), (93, 94...
# 34   [(1, 3), (17, 17), (36, 43), (57, 63), (81, 81)]
# 35                       [(1, 7), (23, 24), (35, 35)]
# 36                                                 []
# 37                                [(1, 22), (33, 33)]
# 38  [(1, 20), (30, 30), (50, 50), (63, 64), (94, 95)]
# 39             [(1, 2), (19, 21), (42, 43), (73, 74)]
# 40  [(1, 6), (23, 25), (40, 41), (50, 53), (69, 74...
# 41                                          [(1, 10)]
# 42                                                 []
# 43                               [(75, 80), (91, 94)]
# 44  [(1, 2), (12, 12), (22, 23), (55, 57), (81, 81...
# 45  [(1, 2), (11, 11), (29, 30), (54, 55), (72, 72...
# 46   [(1, 2), (12, 12), (24, 24), (47, 48), (68, 68)]
# 47                                                 []
# 48                                                 []
# 49   [(1, 4), (21, 23), (41, 41), (65, 65), (79, 83)]
#
#                                              AC_types  \
# 0                                                  []
# 1                                      ['MajorClaim']
# 2          ['Claim', 'Premise', 'Premise', 'Premise']
# 3   ['Premise', 'Claim', 'Premise', 'Premise', 'Cl...
# 4                                      ['MajorClaim']
# 5                                                  []
# 6                                      ['MajorClaim']
# 7   ['Premise', 'Premise', 'Premise', 'Premise', '...
# 8   ['Premise', 'Premise', 'Premise', 'Premise', '...
# 9                             ['Claim', 'MajorClaim']
# 10                                                 []
# 11                                     ['MajorClaim']
# 12         ['Premise', 'Premise', 'Premise', 'Claim']
# 13         ['Premise', 'Premise', 'Premise', 'Claim']
# 14                                     ['MajorClaim']
# 15                                                 []
# 16                                     ['MajorClaim']
# 17         ['Premise', 'Premise', 'Premise', 'Claim']
# 18         ['Premise', 'Premise', 'Premise', 'Claim']
# 19                    ['Premise', 'Premise', 'Claim']
# 20                                                 []
# 21                                                 []
# 22                                     ['MajorClaim']
# 23         ['Premise', 'Premise', 'Premise', 'Claim']
# 24  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 25                            ['MajorClaim', 'Claim']
# 26                                                 []
# 27                       ['MajorClaim', 'MajorClaim']
# 28  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 29  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 30                                     ['MajorClaim']
# 31                                                 []
# 32                 ['MajorClaim', 'Premise', 'Claim']
# 33  ['Premise', 'Premise', 'Premise', 'Claim', 'Pr...
# 34  ['Premise', 'Premise', 'Premise', 'Claim', 'Pr...
# 35                   ['Claim', 'MajorClaim', 'Claim']
# 36                                                 []
# 37                            ['MajorClaim', 'Claim']
# 38  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 39         ['Claim', 'Premise', 'Premise', 'Premise']
# 40  ['Claim', 'Premise', 'Premise', 'Premise', 'Pr...
# 41                                     ['MajorClaim']
# 42                                                 []
# 43                            ['Claim', 'MajorClaim']
# 44  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 45  ['Premise', 'Premise', 'Premise', 'Premise', '...
# 46  ['Claim', 'Premise', 'Premise', 'Premise', 'Ma...
# 47                                                 []
# 48                                                 []
# 49  ['Claim', 'Premise', 'Premise', 'Premise', 'Pr...
#
#                                             AR_pairs  \
# 0                                                 []
# 1                                                 []
# 2                           [(0, 1), (0, 2), (0, 3)]
# 3                           [(1, 0), (4, 2), (4, 3)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                   [(4, 0), (4, 1), (4, 2), (4, 3)]
# 8           [(5, 0), (0, 1), (5, 2), (5, 3), (5, 4)]
# 9                                                 []
# 10                                                []
# 11                                                []
# 12                          [(3, 0), (3, 1), (3, 2)]
# 13                          [(3, 0), (3, 1), (3, 2)]
# 14                                                []
# 15                                                []
# 16                                                []
# 17                          [(3, 0), (3, 1), (3, 2)]
# 18                          [(3, 0), (3, 1), (3, 2)]
# 19                                  [(2, 0), (2, 1)]
# 20                                                []
# 21                                                []
# 22                                                []
# 23                          [(3, 0), (3, 1), (3, 2)]
# 24          [(5, 0), (5, 1), (5, 2), (2, 3), (5, 4)]
# 25                                                []
# 26                                                []
# 27                                                []
# 28          [(4, 0), (0, 1), (4, 2), (4, 3), (4, 5)]
# 29  [(4, 0), (4, 1), (4, 2), (4, 3), (4, 5), (4, 6)]
# 30                                                []
# 31                                                []
# 32                                          [(2, 1)]
# 33                  [(3, 0), (3, 1), (3, 2), (5, 4)]
# 34                  [(3, 0), (3, 1), (3, 2), (3, 4)]
# 35                                                []
# 36                                                []
# 37                                                []
# 38                  [(4, 0), (4, 1), (4, 2), (4, 3)]
# 39                          [(0, 1), (0, 2), (0, 3)]
# 40          [(0, 1), (1, 2), (5, 3), (5, 4), (5, 6)]
# 41                                                []
# 42                                                []
# 43                                                []
# 44  [(6, 0), (2, 1), (6, 2), (6, 3), (6, 4), (6, 5)]
# 45          [(5, 0), (5, 1), (3, 2), (5, 3), (5, 4)]
# 46                          [(0, 1), (0, 2), (0, 3)]
# 47                                                []
# 48                                                []
# 49                  [(0, 1), (0, 2), (0, 3), (0, 4)]
#
#                                              AR_types  split
# 0                                                  []  TRAIN
# 1                                                  []  TRAIN
# 2                   ['Support', 'Support', 'Support']  TRAIN
# 3                   ['Support', 'Support', 'Support']  TRAIN
# 4                                                  []  TRAIN
# 5                                                  []  TRAIN
# 6                                                  []  TRAIN
# 7        ['Support', 'Support', 'Support', 'Support']  TRAIN
# 8   ['Support', 'Support', 'Support', 'Support', '...  TRAIN
# 9                                                  []  TRAIN
# 10                                                 []  TRAIN
# 11                                                 []  TRAIN
# 12                  ['Support', 'Support', 'Support']  TRAIN
# 13                  ['Support', 'Support', 'Support']  TRAIN
# 14                                                 []  TRAIN
# 15                                                 []   TEST
# 16                                                 []   TEST
# 17                  ['Support', 'Support', 'Support']   TEST
# 18                  ['Support', 'Support', 'Support']   TEST
# 19                             ['Support', 'Support']   TEST
# 20                                                 []   TEST
# 21                                                 []   TEST
# 22                                                 []   TEST
# 23                  ['Support', 'Support', 'Support']   TEST
# 24  ['Support', 'Support', 'Attack', 'Attack', 'Su...   TEST
# 25                                                 []   TEST
# 26                                                 []   TEST
# 27                                                 []   TEST
# 28  ['Support', 'Support', 'Support', 'Support', '...   TEST
# 29  ['Support', 'Support', 'Support', 'Support', '...   TEST
# 30                                                 []   TEST
# 31                                                 []  TRAIN
# 32                                        ['Support']  TRAIN
# 33       ['Support', 'Support', 'Support', 'Support']  TRAIN
# 34       ['Support', 'Support', 'Support', 'Support']  TRAIN
# 35                                                 []  TRAIN
# 36                                                 []  TRAIN
# 37                                                 []  TRAIN
# 38       ['Support', 'Support', 'Support', 'Support']  TRAIN
# 39                  ['Support', 'Support', 'Support']  TRAIN
# 40  ['Support', 'Support', 'Support', 'Support', '...  TRAIN
# 41                                                 []  TRAIN
# 42                                                 []  TRAIN
# 43                                                 []  TRAIN
# 44  ['Support', 'Support', 'Support', 'Support', '...  TRAIN
# 45  ['Support', 'Support', 'Support', 'Support', '...  TRAIN
# 46                   ['Support', 'Support', 'Attack']  TRAIN
# 47                                                 []  TRAIN
# 48                                                 []  TRAIN
# 49       ['Support', 'Support', 'Support', 'Support']  TRAIN

# %%
def get_ac_count(x):

    return len(ast.literal_eval(x.AC_types))

# %%
pe_df["AC_count"] = pe_df.apply(lambda x: get_ac_count(x), axis=1)

# %%
# pe_df

# %%
pe_df.split.value_counts()
# Out:
# split
# TRAIN    1796
# TEST      439
# Name: count, dtype: int64

# %%
pe_df
# Out:
#       essay_id  para_id  para_types  \
# 0            0        0      prompt
# 1            0        1       intro
# 2            0        2        body
# 3            0        3        body
# 4            0        4  conclusion
# ...        ...      ...         ...
# 2230       401     2230      prompt
# 2231       401     2231       intro
# 2232       401     2232        body
# 2233       401     2233        body
# 2234       401     2234  conclusion
#
#                                               para_text  \
# 0     <prompt> Should students be taught to compete ...
# 1     <para-intro> It is always said that competitio...
# 2     <para-body> First of all , <AC> through cooper...
# 3     <para-body> On the other hand , <AC> the signi...
# 4     <para-conclusion> Consequently , no matter fro...
# ...                                                 ...
# 2230  <prompt> A greater proportion of the budget sh...
# 2231  <para-intro> In today ' s world , the concept ...
# 2232  <para-body> <AC> The first reason why educatio...
# 2233  <para-body> The second reason why <AC> governm...
# 2234  <para-conclusion> In conclusion , <AC> a great...
#
#                                               adu_spans  \
# 0                                                    []
# 1                                            [(76, 97)]
# 2             [(1, 25), (26, 55), (56, 99), (100, 123)]
# 3     [(1, 22), (24, 37), (39, 63), (76, 139), (155,...
# 4                                             [(1, 40)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(26, 51)]
# 2232            [(0, 22), (24, 56), (58, 71), (72, 98)]
# 2233           [(1, 25), (27, 53), (55, 88), (90, 128)]
# 2234                                          [(1, 37)]
#
#                                                ac_spans  \
# 0                                                    []
# 1                                            [(86, 97)]
# 2             [(5, 25), (27, 55), (57, 99), (101, 123)]
# 3     [(6, 22), (30, 37), (41, 63), (77, 139), (156,...
# 4                                            [(25, 40)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(33, 51)]
# 2232            [(1, 22), (27, 56), (60, 71), (74, 98)]
# 2233           [(5, 25), (31, 53), (57, 88), (93, 128)]
# 2234                                          [(4, 37)]
#
#                                                ai_spans  \
# 0                                                    []
# 1                                            [(76, 85)]
# 2              [(1, 4), (26, 26), (56, 56), (100, 100)]
# 3     [(1, 5), (24, 29), (39, 40), (76, 76), (155, 1...
# 4                                             [(1, 24)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(26, 32)]
# 2232             [(0, 0), (24, 26), (58, 59), (72, 73)]
# 2233             [(1, 4), (27, 30), (55, 56), (90, 92)]
# 2234                                           [(1, 3)]
#
#                                                AC_types  \
# 0                                                    []
# 1                                        ['MajorClaim']
# 2            ['Claim', 'Premise', 'Premise', 'Premise']
# 3     ['Premise', 'Claim', 'Premise', 'Premise', 'Cl...
# 4                                        ['MajorClaim']
# ...                                                 ...
# 2230                                                 []
# 2231                                     ['MajorClaim']
# 2232         ['Premise', 'Premise', 'Claim', 'Premise']
# 2233         ['Claim', 'Premise', 'Premise', 'Premise']
# 2234                                     ['MajorClaim']
#
#                       AR_pairs                           AR_types  split  \
# 0                           []                                 []  TRAIN
# 1                           []                                 []  TRAIN
# 2     [(0, 1), (0, 2), (0, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 3     [(1, 0), (4, 2), (4, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 4                           []                                 []  TRAIN
# ...                        ...                                ...    ...
# 2230                        []                                 []  TRAIN
# 2231                        []                                 []  TRAIN
# 2232  [(2, 0), (2, 1), (2, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 2233  [(2, 1), (0, 2), (2, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 2234                        []                                 []  TRAIN
#
#       AC_count
# 0            0
# 1            1
# 2            4
# 3            5
# 4            1
# ...        ...
# 2230         0
# 2231         1
# 2232         4
# 2233         4
# 2234         1
#
# [2235 rows x 12 columns]

# %%
def get_ar_pair_count(x):

    return len(ast.literal_eval(x.AR_pairs))

# %%
pe_df["AR_count"] = pe_df.apply(lambda x: get_ar_pair_count(x), axis=1)

# %%
# Remove paragraphs with 0 ACs

# %%
#pe_df = pe_df[pe_df.AC_count > 0].reset_index()

# %%
pe_df
# Out:
#       essay_id  para_id  para_types  \
# 0            0        0      prompt
# 1            0        1       intro
# 2            0        2        body
# 3            0        3        body
# 4            0        4  conclusion
# ...        ...      ...         ...
# 2230       401     2230      prompt
# 2231       401     2231       intro
# 2232       401     2232        body
# 2233       401     2233        body
# 2234       401     2234  conclusion
#
#                                               para_text  \
# 0     <prompt> Should students be taught to compete ...
# 1     <para-intro> It is always said that competitio...
# 2     <para-body> First of all , <AC> through cooper...
# 3     <para-body> On the other hand , <AC> the signi...
# 4     <para-conclusion> Consequently , no matter fro...
# ...                                                 ...
# 2230  <prompt> A greater proportion of the budget sh...
# 2231  <para-intro> In today ' s world , the concept ...
# 2232  <para-body> <AC> The first reason why educatio...
# 2233  <para-body> The second reason why <AC> governm...
# 2234  <para-conclusion> In conclusion , <AC> a great...
#
#                                               adu_spans  \
# 0                                                    []
# 1                                            [(76, 97)]
# 2             [(1, 25), (26, 55), (56, 99), (100, 123)]
# 3     [(1, 22), (24, 37), (39, 63), (76, 139), (155,...
# 4                                             [(1, 40)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(26, 51)]
# 2232            [(0, 22), (24, 56), (58, 71), (72, 98)]
# 2233           [(1, 25), (27, 53), (55, 88), (90, 128)]
# 2234                                          [(1, 37)]
#
#                                                ac_spans  \
# 0                                                    []
# 1                                            [(86, 97)]
# 2             [(5, 25), (27, 55), (57, 99), (101, 123)]
# 3     [(6, 22), (30, 37), (41, 63), (77, 139), (156,...
# 4                                            [(25, 40)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(33, 51)]
# 2232            [(1, 22), (27, 56), (60, 71), (74, 98)]
# 2233           [(5, 25), (31, 53), (57, 88), (93, 128)]
# 2234                                          [(4, 37)]
#
#                                                ai_spans  \
# 0                                                    []
# 1                                            [(76, 85)]
# 2              [(1, 4), (26, 26), (56, 56), (100, 100)]
# 3     [(1, 5), (24, 29), (39, 40), (76, 76), (155, 1...
# 4                                             [(1, 24)]
# ...                                                 ...
# 2230                                                 []
# 2231                                         [(26, 32)]
# 2232             [(0, 0), (24, 26), (58, 59), (72, 73)]
# 2233             [(1, 4), (27, 30), (55, 56), (90, 92)]
# 2234                                           [(1, 3)]
#
#                                                AC_types  \
# 0                                                    []
# 1                                        ['MajorClaim']
# 2            ['Claim', 'Premise', 'Premise', 'Premise']
# 3     ['Premise', 'Claim', 'Premise', 'Premise', 'Cl...
# 4                                        ['MajorClaim']
# ...                                                 ...
# 2230                                                 []
# 2231                                     ['MajorClaim']
# 2232         ['Premise', 'Premise', 'Claim', 'Premise']
# 2233         ['Claim', 'Premise', 'Premise', 'Premise']
# 2234                                     ['MajorClaim']
#
#                       AR_pairs                           AR_types  split  \
# 0                           []                                 []  TRAIN
# 1                           []                                 []  TRAIN
# 2     [(0, 1), (0, 2), (0, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 3     [(1, 0), (4, 2), (4, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 4                           []                                 []  TRAIN
# ...                        ...                                ...    ...
# 2230                        []                                 []  TRAIN
# 2231                        []                                 []  TRAIN
# 2232  [(2, 0), (2, 1), (2, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 2233  [(2, 1), (0, 2), (2, 3)]  ['Support', 'Support', 'Support']  TRAIN
# 2234                        []                                 []  TRAIN
#
#       AC_count  AR_count
# 0            0         0
# 1            1         0
# 2            4         3
# 3            5         3
# 4            1         0
# ...        ...       ...
# 2230         0         0
# 2231         1         0
# 2232         4         3
# 2233         4         3
# 2234         1         0
#
# [2235 rows x 13 columns]

# %%
pe_df.split.value_counts()
# Out:
# split
# TRAIN    1796
# TEST      439
# Name: count, dtype: int64

# %% [markdown]
# ## Prepare prompt

# %% [raw]
# Prompt Template 1:
#
# Paragrapht Text, ACs, AR pairs.
#
# <instruction> You are an expert in Argument Mining. You are given a paragraph and a numbered list of argument components. Your task is to identify argument relations in the paragraph given as pairs of argument component numbers.
# <input> paragraph text, numbered list of ACs
# <output> (2, 4), (2, 5), (3, 1)
#
#
# Prompt Template 2:
#
# Paragraph Text with ACs, AR pairs.
#
# <instruction> You are an expert in Argument Mining. You are given a paragraph with argument components. Your task is to identify argument relations in the paragraph given as pairs of argument component numbers.
# <input> paragraph text, numbered ACs
# <output> (2, 4), (2, 5), (3, 1)
#
# We start with template 2.
#
# # You must return a JSON with format {\"Argument 1\": <predicted class for Argument 1 (str)>, ..., \"Argument n\": <predicted class for Argument n (str)>}\n\n### Class definitions:\nMajorClaim="
#
# You must return a list of ac pairs in JSON format: {{"list of ACs": [(target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]}}

# %%
def formatting_fct(instruction="", input="", output="", mode="train"):
    
    prompt_d ={
            
        "instruction": f"""{instruction}""",
        "input": f"""{input}""",
        "output": f"""{output if mode=='train' else ''}"""
            
        }
    
    return prompt_d

# %%
instruction = """### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}
"""

# %%
print(instruction)
# Out:
# ### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}

# %%
def replace_substring_with_position(main_string, substring, ac_types):
    result = ""
    start = 0
    current_index = 0
    position = 0  # Initialize position counter
    
    while current_index < len(main_string):
        current_index = main_string.find(substring, current_index)
        if current_index == -1:
            break
        
        # Append part of the string before the current match
        result += main_string[start:current_index]
        
        # Append the replacement
        sstring = substring[:-1]
        ac_type = ac_types[position]
        
        # result += f"{sstring}{position}, {ac_type}>"
        result += f"{sstring}{position}>"
        
        # Update the start to be the end of the current match
        start = current_index + len(substring)
        current_index = start
        
        # Increment the position counter
        position += 1
    
    # Append any remaining part of the string
    result += main_string[start:]
    
    return result

# %%
def build_input(paragraph, ac_types, ar_pairs):
    
    paragraph = paragraph.replace("<prompt> ", "<topic> ")
    paragraph = paragraph.replace(" </prompt>", " </topic>")
    # comment next line to keep para tags.
    paragraph = paragraph.replace("<topic> ", "")
    paragraph = paragraph.replace(" </topic>", "")
    paragraph = paragraph.replace("<para-intro> ", "")
    paragraph = paragraph.replace(" </para-intro>", "")
    paragraph = paragraph.replace("<para-body> ", "")
    paragraph = paragraph.replace(" </para-body>", "")
    paragraph = paragraph.replace("<para-conclusion> ", "")
    paragraph = paragraph.replace(" </para-conclusion>", "")
    
    
    paragraph = replace_substring_with_position(paragraph, "<AC>", ast.literal_eval(ac_types))
    paragraph = replace_substring_with_position(paragraph, "</AC>", ast.literal_eval(ac_types))

    
    question = f"""### Here is the paragraph text: {paragraph}\n###Here is the list of pairs of related argument components in this paragraph: {ar_pairs}"""
    
    return question

# %%
def build_answer(ar_types):

    
    return json.dumps({"relation_types": ast.literal_eval(ar_types)})

# %%
# print(formatting_fct(instruction, question, answer, mode="train"))

# %%
pe_df.split.value_counts()
# Out:
# split
# TRAIN    1796
# TEST      439
# Name: count, dtype: int64

# %% [markdown]
# ## Prepare data files

# %% [markdown]
# ### Train set

# %%
data_file_train = []

for i, _ in pe_df[pe_df["split"] == "TRAIN"].iterrows():

    question = build_input(pe_df.iloc[i].para_text, pe_df.iloc[i].AC_types, pe_df.iloc[i].AR_pairs)
    answer = build_answer(pe_df.iloc[i].AR_types)
    
    data_file_train.append( formatting_fct(instruction, question, answer, mode="train") )

# %%
len(data_file_train)
# Out:
# 1796

# %%
for i in range(3):
    
    print(data_file_train[i])
    print()
# Out:
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: Should students be taught to compete or to cooperate ?\n###Here is the list of pairs of related argument components in this paragraph: []', 'output': '{"relation_types": []}'}
#
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': "### Here is the paragraph text: It is always said that competition can effectively promote the development of economy . In order to survive in the competition , companies continue to improve their products and service , and as a result , the whole society prospers . However , when we discuss the issue of competition or cooperation , what we are concerned about is not the whole society , but the development of an individual ' s whole life . From this point of view , I firmly believe that <AC0> we should attach more importance to cooperation during primary education </AC0> .\n###Here is the list of pairs of related argument components in this paragraph: []", 'output': '{"relation_types": []}'}
#
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: First of all , <AC0> through cooperation , children can learn about interpersonal skills which are significant in the future life of all students </AC0> . <AC1> What we acquired from team work is not only how to achieve the same goal with others but more importantly , how to get along with others </AC1> . <AC2> During the process of cooperation , children can learn about how to listen to opinions of others , how to communicate with others , how to think comprehensively , and even how to compromise with other team members when conflicts occurred </AC2> . <AC3> All of these skills help them to get on well with other people and will benefit them for the whole life </AC3> .\n###Here is the list of pairs of related argument components in this paragraph: [(0, 1), (0, 2), (0, 3)]', 'output': '{"relation_types": ["Support", "Support", "Support"]}'}

# %%
print(data_file_train[674])
# Out:
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: In short , I can say for certain that <AC0> spending money on improving public transportation is necessary </AC0> because <AC1> it is the key to protect our world , creating a healthy and safe environment for people to live in </AC1> .\n###Here is the list of pairs of related argument components in this paragraph: []', 'output': '{"relation_types": []}'}

# %%
print(data_file_train[2]["output"])
# Out:
# {"relation_types": ["Support", "Support", "Support"]}

# %%
len(data_file_train)
# Out:
# 1796

# %%
type(json.loads(data_file_train[2]["output"])["relation_types"])
# Out:
# list

# %% [markdown]
# ### Validation set (optional)

# %%
# val_length = int(1417/10)

# %%
# val_length

# %%
# data_file_val = random.sample(data_file_train, val_length)

# %%
# len(data_file_val)

# %%
# data_file_train = [message for message in data_file_train if message not in data_file_val]

# %%
# len(data_file_train)

# %%
# data_file_val = []

# for i, _ in df[df["essay_file"].isin(val_essays_l)].iterrows():
    
#     question = build_question(df.iloc[i].argument_component)
#     answer = build_answer(df.iloc[i].label)
    
#     data_file_val.append( formatting_fct(my_task_description, question, answer, mode="train") )

# %%
#len(data_file_val)

# %%
# for i in range(3):
    
#     print(data_file_val[i])
#     print()

# %% [markdown]
# ### Test set

# %%
data_file_test = []

for i, _ in pe_df[pe_df.split == "TEST"].iterrows():
    
    question = build_input(pe_df.iloc[i].para_text, pe_df.iloc[i].AC_types, pe_df.iloc[i].AR_pairs)
    answer = build_answer(pe_df.iloc[i].AR_types)
    
    data_file_test.append( formatting_fct(instruction, question, answer, mode="train") )

# %%
len(data_file_test)
# Out:
# 439

# %%
for i in range(3):
    
    print(data_file_test[i])
    print()
# Out:
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: Will newspapers become a thing of the past ?\n###Here is the list of pairs of related argument components in this paragraph: []', 'output': '{"relation_types": []}'}
#
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: The internet has been more and more popular for recent years , providing people with a huge source of information . As a result of this , print media such as newspapers have experienced a dramatic decline in the number of readers . Some people , however , still believe that they can exist for long time ; others disagree , arguing that <AC0> newspapers have lost their competitive advantage to sustain their prolonged existence </AC0> . Personally , I am inclined to agree with the latter view for following reasons .\n###Here is the list of pairs of related argument components in this paragraph: []', 'output': '{"relation_types": []}'}
#
# {'instruction': '### You are an expert in Argument Mining. You are given a paragraph which contains argument components enclosed by <AC></AC> tags. You are also given a list of pairs of related argument components in the form: [(target AC (int), source AC (int)), (target AC (int), source AC (int)), ..., (target AC (int), source AC (int))]. Your task is to classify each pair of related argument components in the list as either "Support" or "Attack". You must return a list of relation types in following JSON format: {"relation_types": [relation_type (str), relation_type (str), ..., relation_type (str)]}\n', 'input': '### Here is the paragraph text: First of all , <AC0> to obtain information , using the internet is quicker and more convenient than reading newspapers </AC0> . <AC1> Contrary to the past when people had to wait long hours to take a daily newspaper , nowadays , they can acquire latest news updated every second through their mobile phones or computers connected to the internet , everywhere and at anytime </AC1> . <AC2> As can be seen , these devices and machines are very common in all parts of the world , making it easier for people to read a number of things that newspapers can not provide in only some pages </AC2> . Hence , <AC3> the print media has failed to keep its important role in the provision of information </AC3> .\n###Here is the list of pairs of related argument components in this paragraph: [(3, 0), (3, 1), (3, 2)]', 'output': '{"relation_types": ["Support", "Support", "Support"]}'}

# %% [markdown]
# ## Save `jsonl` files

# %%
file_path = os.path.join(os.getcwd(), "datasets/PE_LTC_paragraph_wo_tags_train.json")

with open(file_path, 'w') as file:
    
    json.dump(data_file_train, file)

# %%
file_path = os.path.join(os.getcwd(), "datasets/PE_LTC_paragraph_wo_tags_test.json")

with open(file_path, 'w') as file:
    
    json.dump(data_file_test, file)

# %%
# file_path = os.path.join(os.getcwd(), "datasets/PE_LI_val.json")

# with open(file_path, 'w') as file:
    
#     json.dump(data_file_val, file)
