# %% [markdown]
# # Joint Task Post-Processing

# %% [markdown]
# ## Libraries

# %%
import os
import pickle
import json
import pandas as pd
import ast

# %%
nb_epochs = 10
output_dir = "models/PE_ATC-LI-LTC_paragraph_wo_tags_llama-3-8b-Instruct"

# %%
with open(os.path.join(output_dir, f"""PE_ATC-LI-LTC_results_{nb_epochs}.pickle"""), "rb") as fh:
        
        results = pickle.load(fh)

# %%
results
# Out:
# {'ground_truths': ['{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[5, 0, "Support"], [5, 1, "Support"], [5, 2, "Attack"], [2, 3, "Attack"], [5, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[4, 0, "Support"], [0, 1, "Support"], [4, 2, "Support"], [4, 3, "Support"], [4, 5, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[4, 0, "Support"], [4, 1, "Support"], [4, 2, "Support"], [4, 3, "Support"], [4, 5, "Support"], [4, 6, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[2, 0, "Support"], [0, 1, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [4, 3, "Attack"], [4, 5, "Support"], [4, 6, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"], [6, 2, "Support"], [6, 3, "Support"], [3, 4, "Support"], [3, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[5, 0, "Support"], [2, 1, "Support"], [5, 2, "Support"], [4, 3, "Support"], [5, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim"], "list_argument_relations_and_types": [[1, 0, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [4, 5, "Support"], [4, 6, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"], [0, 6, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[4, 0, "Support"], [4, 1, "Support"], [4, 2, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"], [0, 5, "Support"], [5, 6, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Attack"], [4, 5, "Support"], [5, 6, "Attack"]]}',
#   '{"list_component_types": ["Claim", "Claim", "Premise", "MajorClaim"], "list_argument_relations_and_types": [[1, 2, "Support"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [1, 2, "Support"], [0, 3, "Attack"], [0, 4, "Attack"]]}',
#   '{"list_component_types": ["MajorClaim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Attack"], [0, 3, "Attack"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Attack"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [4, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Attack"], [2, 3, "Attack"], [2, 4, "Attack"], [0, 5, "Support"], [5, 6, "Support"], [5, 7, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim", "Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"], [2, 3, "Support"], [3, 4, "Support"], [5, 6, "Support"], [6, 7, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 0, "Support"], [0, 1, "Support"], [2, 3, "Support"], [2, 4, "Support"], [2, 5, "Support"], [2, 6, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"], [2, 3, "Support"], [2, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[1, 0, "Support"], [4, 1, "Support"], [1, 2, "Support"], [4, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"], [0, 6, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [4, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Attack"], [1, 2, "Support"], [2, 3, "Support"], [2, 4, "Support"], [2, 5, "Support"], [1, 6, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [0, 2, "Attack"], [0, 3, "Attack"], [0, 4, "Attack"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [1, 2, "Attack"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [0, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"], [3, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [4, 5, "Support"], [7, 6, "Support"], [0, 7, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 2, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"], [1, 4, "Support"], [1, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [0, 2, "Attack"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"], [4, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"], [2, 4, "Support"], [2, 5, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"], [3, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"], [1, 4, "Support"], [1, 5, "Support"], [1, 6, "Support"]]}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"], [1, 4, "Support"], [1, 5, "Support"], [1, 6, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [0, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"], [0, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "MajorClaim"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[4, 1, "Support"], [4, 2, "Support"], [4, 3, "Support"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "MajorClaim"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [3, 2, "Support"], [0, 3, "Attack"], [5, 4, "Support"], [0, 5, "Attack"], [5, 6, "Support"], [6, 7, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"], [4, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"], [0, 6, "Support"], [0, 7, "Support"], [0, 8, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [4, 3, "Support"], [5, 4, "Support"], [0, 5, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [1, 3, "Support"], [1, 4, "Support"], [1, 5, "Support"], [1, 6, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim", "Premise"], "list_argument_relations_and_types": [[1, 2, "Attack"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [4, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [0, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"], [3, 5, "Support"], [7, 6, "Support"], [3, 7, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"], [5, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Attack"], [2, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Attack"], [2, 3, "Attack"], [2, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim"], "list_argument_relations_and_types": [[1, 0, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"], [3, 4, "Attack"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 2, "Support"], [1, 3, "Support"], [1, 4, "Support"]]}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[7, 0, "Support"], [7, 1, "Support"], [1, 2, "Support"], [7, 3, "Support"], [7, 4, "Support"], [4, 5, "Support"], [4, 6, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Attack"], [3, 4, "Attack"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[1, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[0, 1, "Support"], [4, 2, "Support"], [4, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [0, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [0, 1, "Support"]]}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [3, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [4, 5, "Support"], [4, 6, "Support"], [4, 7, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Claim", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [3, 2, "Support"], [4, 3, "Support"], [4, 5, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[9, 0, "Support"], [9, 1, "Support"], [9, 2, "Support"], [9, 3, "Support"], [3, 4, "Support"], [3, 5, "Support"], [3, 6, "Support"], [3, 7, "Attack"], [7, 8, "Attack"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"], [5, 6, "Support"], [5, 7, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[5, 0, "Support"], [5, 1, "Support"], [5, 2, "Support"], [5, 3, "Support"], [5, 4, "Support"]]}',
#   '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}',
#   '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"]]}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": [], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}',
#   '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}',
# ...
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [3, 4, "Support"], [3, 5, "Support"], [3, 6, "Support"], [3, 7, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[5, 0, "Support"], [5, 1, "Support"], [5, 2, "Support"], [5, 3, "Support"], [5, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [4, 2, "Support"], [4, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"], [0, 6, "Support"], [0, 7, "Support"], [7, 8, "Support"], [0, 9, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim", "Claim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"], [2, 4, "Support"], [0, 5, "Support"], [5, 6, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [2, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [1, 3, "Support"], [3, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[1, 0, "Support"], [1, 2, "Support"], [1, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[6, 0, "Support"], [6, 1, "Attack"], [1, 2, "Attack"], [1, 3, "Attack"], [6, 4, "Support"], [6, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [0, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [0, 4, "Support"], [0, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"], [0, 3, "Support"], [3, 4, "Support"], [0, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[2, 1, "Support"], [0, 2, "Support"], [2, 3, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Premise", "Premise", "Claim", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[4, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"], [4, 3, "Support"], [6, 5, "Support"], [7, 6, "Support"], [4, 7, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Support"], [4, 3, "Support"], [0, 4, "Support"], [4, 5, "Support"], [0, 6, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Premise", "Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[3, 0, "Support"], [3, 1, "Support"], [3, 2, "Support"], [3, 4, "Support"], [3, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [1, 2, "Attack"], [0, 3, "Support"], [5, 4, "Support"], [0, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise", "Premise", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Attack"], [1, 2, "Attack"], [0, 3, "Support"], [3, 4, "Support"], [3, 5, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim", "Premise"], "list_argument_relations_and_types": [[1, 2, "Attack"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": [], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim"], "list_argument_relations_and_types": []}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Premise", "Premise", "Claim"], "list_argument_relations_and_types": [[2, 0, "Support"], [2, 1, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["Claim", "Premise", "Premise"], "list_argument_relations_and_types": [[0, 1, "Support"], [0, 2, "Support"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_component_types": ["MajorClaim", "Claim"], "list_argument_relations_and_types": []}'}]}

# %%
grounds_global = results["ground_truths"]

# %%
preds_global = results["predictions"]

# %%
len(grounds_global), len(preds_global)
# Out:
# (439, 439)

# %% [markdown]
# ## ATC post-processing

# %%
grounds = [json.loads(x)["list_component_types"] for x in grounds_global]

# %%
preds = [x["content"] for x in preds_global]

# %%
preds = [json.loads(x)["list_component_types"] for x in preds]

# %%
len(grounds), len(preds)
# Out:
# (439, 439)

# %%
grounds
# Out:
# [[],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim'],
#  [],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  [],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Claim', 'Premise', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Claim', 'Premise'],
#  ['Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  [],
#  ['Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['Claim', 'Premise', 'Premise', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Premise', 'Premise', 'Premise', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Premise'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Claim', 'Premise', 'Premise', 'Premise'],
#  [],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim', 'Claim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim'],
#  [],
#  [],
#  ['Claim', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim']]

# %%
preds
# Out:
# [[],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  [],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise'],
#  [],
#  [],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim'],
#  [],
#  ['Claim', 'Premise', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Claim', 'Premise'],
#  ['Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Claim',
#   'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim', 'Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['Claim', 'Premise', 'Premise', 'MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim', 'Claim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Premise'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  [],
#  [],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Claim', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim'],
#  ['MajorClaim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['Claim', 'MajorClaim'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim', 'Claim', 'Claim', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim'],
#  [],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Claim'],
#  [],
#  [],
#  ['Claim', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Claim', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Claim'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  [],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim'],
#  [],
#  ['MajorClaim'],
#  ['Premise',
#   'Premise',
#   'Premise',
#   'Premise',
#   'Claim',
#   'Premise',
#   'Premise',
#   'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Premise', 'Premise', 'Premise', 'Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim'],
#  [],
#  ['MajorClaim'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['Claim', 'Premise', 'Premise', 'Premise', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim', 'Premise'],
#  [],
#  ['MajorClaim'],
#  ['Premise', 'Premise', 'Claim'],
#  ['Claim', 'Premise', 'Premise'],
#  ['MajorClaim', 'Claim']]

# %%
def opposite(component_type):

    if component_type == "Premise":
        return "Claim"
    elif component_type == "Claim":
        return "Premise"
    elif component_type == "MajorClaim":
        return "Claim"

# %%
def harmonize_preds(grounds, preds):

    l1, l2 = len(preds), len(grounds)
    if l1 < l2:
        diff = l2 - l1
        preds = preds + [opposite(x) for x in grounds[l1:]]
    else:
        preds = preds[:l2]
        
    return preds

# %%
for i,(x,y) in enumerate(zip(grounds, preds)):
    
    if len(x) != len(y):
        
        preds[i] = harmonize_preds(x, y)

# %%
ATC_preds = [item for row in preds for item in row]
ATC_grounds = [item for row in grounds for item in row]

# %%
# sanity check: 
len(ATC_preds) == len(ATC_grounds)
# Out:
# True

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ATC_grounds, ATC_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        Claim      0.774     0.784     0.779       283
#   MajorClaim      0.979     0.922     0.950       154
#      Premise      0.916     0.923     0.919       724
#
#     accuracy                          0.889      1161
#    macro avg      0.890     0.876     0.883      1161
# weighted avg      0.890     0.889     0.889      1161

# %%
### ARI post-processing

# %%
len(grounds_global), len(preds_global)
# Out:
# (439, 439)

# %%
grounds = [json.loads(x)["list_argument_relations_and_types"] for x in grounds_global]

preds = [x["content"] for x in preds_global]

preds = [json.loads(x)["list_argument_relations_and_types"] for x in preds]

# %%
grounds
# Out:
# [[],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[5, 0, 'Support'],
#   [5, 1, 'Support'],
#   [5, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [5, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [0, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support']],
#  [[4, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [0, 1, 'Support'], [2, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [4, 3, 'Attack'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [[2, 0, 'Support'],
#   [2, 1, 'Support'],
#   [6, 2, 'Support'],
#   [6, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [0, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [2, 1, 'Support'],
#   [5, 2, 'Support'],
#   [4, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Attack'],
#   [4, 5, 'Support'],
#   [5, 6, 'Attack']],
#  [[1, 2, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Support'], [0, 3, 'Attack'], [0, 4, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Attack'], [0, 3, 'Attack']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [3, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [2, 4, 'Attack'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support'],
#   [5, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [[2, 0, 'Support'],
#   [2, 1, 'Support'],
#   [2, 3, 'Support'],
#   [3, 4, 'Support'],
#   [5, 6, 'Support'],
#   [6, 7, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'],
#   [0, 1, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support'],
#   [2, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [2, 3, 'Support'], [2, 4, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support'], [4, 1, 'Support'], [1, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Attack'],
#   [1, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Attack'], [0, 2, 'Attack'], [0, 3, 'Attack'], [0, 4, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Attack'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[3, 0, 'Support'], [0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [7, 6, 'Support'],
#   [0, 7, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [],
#  [],
#  [[1, 2, 'Support'], [2, 3, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Attack'], [0, 2, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [3, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Attack'],
#   [3, 2, 'Support'],
#   [0, 3, 'Attack'],
#   [5, 4, 'Support'],
#   [0, 5, 'Attack'],
#   [5, 6, 'Support'],
#   [6, 7, 'Support']],
#  [[2, 1, 'Support'],
#   [0, 2, 'Support'],
#   [4, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [0, 8, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [4, 3, 'Support'],
#   [5, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [2, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 2, 'Attack']],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'],
#   [0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [7, 6, 'Support'],
#   [3, 7, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [5, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Attack'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Attack'], [2, 3, 'Attack'], [2, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[1, 2, 'Support'], [1, 3, 'Support'], [1, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[7, 0, 'Support'],
#   [7, 1, 'Support'],
#   [1, 2, 'Support'],
#   [7, 3, 'Support'],
#   [7, 4, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Attack'], [3, 4, 'Attack']],
#  [[1, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [3, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support'],
#   [4, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [4, 3, 'Support'], [4, 5, 'Support']],
#  [[9, 0, 'Support'],
#   [9, 1, 'Support'],
#   [9, 2, 'Support'],
#   [9, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [3, 6, 'Support'],
#   [3, 7, 'Attack'],
#   [7, 8, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support'],
#   [5, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [5, 1, 'Support'],
#   [5, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [7, 8, 'Support'],
#   [0, 9, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Attack'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[1, 0, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[6, 0, 'Support'],
#   [6, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [1, 3, 'Attack'],
#   [6, 4, 'Support'],
#   [6, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [5, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [2, 1, 'Support'],
#   [3, 2, 'Support'],
#   [4, 3, 'Support'],
#   [6, 5, 'Support'],
#   [7, 6, 'Support'],
#   [4, 7, 'Support']],
#  [[5, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [5, 4, 'Support'],
#   [5, 6, 'Support']],
#  [[3, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [0, 3, 'Support'],
#   [0, 4, 'Attack'],
#   [4, 5, 'Attack']],
#  [[2, 0, 'Attack'],
#   [2, 1, 'Attack'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  []]

# %%
preds
# Out:
# [[],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support']],
#  [[4, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Attack'],
#   [3, 4, 'Attack'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[2, 0, 'Support'],
#   [2, 1, 'Support'],
#   [6, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [2, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [2, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Attack'],
#   [4, 5, 'Support'],
#   [5, 6, 'Attack']],
#  [[0, 1, 'Attack'], [1, 2, 'Attack']],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Support'], [0, 3, 'Attack'], [0, 4, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Attack'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support'],
#   [0, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [[1, 0, 'Support'],
#   [2, 1, 'Support'],
#   [2, 3, 'Support'],
#   [3, 4, 'Support'],
#   [5, 'Claim'],
#   [6, 'Claim'],
#   [6, 7, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [1, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[6, 0, 'Attack'],
#   [0, 1, 'Attack'],
#   [6, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Attack'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [7, 6, 'Support'],
#   [0, 7, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [],
#  [],
#  [[2, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [5, 4, 'Support'],
#   [1, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Attack'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [5, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Attack'],
#   [3, 2, 'Support'],
#   [0, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [6, 7, 'Support']],
#  [[2, 1, 'Support'],
#   [0, 2, 'Support'],
#   [4, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [0, 8, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 2, 'Attack']],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [5, 6, 'Support'],
#   [3, 7, 'Support']],
#  [[5, 0, 'Support'],
#   [2, 1, 'Support'],
#   [3, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Attack'], [0, 3, 'Attack']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Attack']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[7, 0, 'Support'],
#   [7, 1, 'Support'],
#   [7, 2, 'Support'],
#   [7, 3, 'Support'],
#   [7, 4, 'Support'],
#   [7, 5, 'Support'],
#   [7, 6, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Attack'], [3, 4, 'Attack']],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Attack'], [2, 3, 'Support'], [0, 4, 'Attack']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [4, 3, 'Support'], [4, 5, 'Support']],
#  [[9, 0, 'Support'],
#   [9, 1, 'Support'],
#   [9, 2, 'Support'],
#   [9, 3, 'Support'],
#   [9, 4, 'Support'],
#   [9, 5, 'Support'],
#   [9, 6, 'Support'],
#   [9, 7, 'Support'],
#   [9, 8, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [3, 6, 'Support'],
#   [3, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [5, 1, 'Support'],
#   [5, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [7, 8, 'Support'],
#   [0, 9, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[6, 0, 'Support'],
#   [6, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [1, 3, 'Attack'],
#   [6, 4, 'Support'],
#   [6, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [4, 3, 'Support'],
#   [6, 5, 'Support'],
#   [7, 6, 'Support'],
#   [4, 7, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [4, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[3, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [1, 2, 'Attack'],
#   [0, 3, 'Support'],
#   [5, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[1, 2, 'Attack']],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  []]

# %%
def get_ar_pairs(grounds):

    grounds_l = []
    
    for sublist in grounds:
        l_tmp = []
        for l in sublist:
            l_tmp.append(l[0:2])
            
        grounds_l.append(l_tmp)

    return grounds_l

# %%
grounds = get_ar_pairs(grounds)
preds = get_ar_pairs(preds)

# %%
len(grounds), len(preds)
# Out:
# (439, 439)

# %%
pe_df = pd.read_csv(os.path.abspath("datasets/PE_data.csv"))

# pe_df

df_split = pd.read_csv("datasets/train-test-split.csv", sep=";")

pe_df['split'] = pe_df['essay_id'].map(df_split['SET'])

# %%
def get_ac_count(x):

    return len(ast.literal_eval(x.AC_types))

# %%
pe_df["AC_count"] = pe_df.apply(lambda x: get_ac_count(x), axis=1)

# %%
def get_all_possible_pairs(x):

    pairs_l = []

    ac_count = x.AC_count
    ar_pairs = ast.literal_eval(x.AR_pairs)
    
    for i in range(ac_count):
        for j in range(ac_count):
            if i != j:
                pair = (i, j)
                if pair in ar_pairs:
                    pairs_l.append([i, j, "Rel"])
                else:
                    pairs_l.append([i, j, "N-Rel"])

    return pairs_l

# %%
pe_df["LI_grounds"] = pe_df.apply(lambda x: get_all_possible_pairs(x), axis=1)

# %%
LI_grounds_l = list(pe_df[pe_df.split == "TEST"].reset_index().LI_grounds)

# %%
def process_preds(test_preds, LI_grounds_l):

    if len(test_preds) != len(LI_grounds_l):
        print("error in preds length")

    preds_pairs_l = []

    for l_1, l_2 in zip(test_preds, LI_grounds_l):
        para_list = []
        for i, j, _ in l_2:
            pair = [i, j]
            if pair in l_1:
                para_list.append([i, j, "Rel"])
            else:
                para_list.append([i, j, "N-Rel"])

        preds_pairs_l.append(para_list)

    return preds_pairs_l

# %%
LI_preds_l = process_preds(preds, LI_grounds_l)

# %%
len(LI_grounds_l) == len(LI_preds_l)
# Out:
# True

# %%
LI_preds = [item for row in LI_preds_l for item in row]
LI_grounds = [item for row in LI_grounds_l for item in row]

# %%
# sanity check: 
len(LI_preds) == len(LI_grounds)
# Out:
# True

# %%
LI_preds = [x[2] for x in LI_preds]
LI_grounds = [x[2] for x in LI_grounds]

# %%
print(classification_report(LI_grounds, LI_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        N-Rel      0.933     0.932     0.933      3384
#          Rel      0.684     0.688     0.686       724
#
#     accuracy                          0.889      4108
#    macro avg      0.809     0.810     0.809      4108
# weighted avg      0.889     0.889     0.889      4108

# %% [markdown]
# ## ARC post-processing

# %%
grounds = [json.loads(x)["list_argument_relations_and_types"] for x in grounds_global]

preds = [x["content"] for x in preds_global]

preds = [json.loads(x)["list_argument_relations_and_types"] for x in preds]

# %%
preds
# Out:
# [[],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support']],
#  [[4, 0, 'Support'],
#   [4, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [4, 5, 'Support'],
#   [4, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Attack'],
#   [3, 4, 'Attack'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[2, 0, 'Support'],
#   [2, 1, 'Support'],
#   [6, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [2, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [2, 1, 'Support'],
#   [4, 2, 'Support'],
#   [4, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Attack'],
#   [4, 5, 'Support'],
#   [5, 6, 'Attack']],
#  [[0, 1, 'Attack'], [1, 2, 'Attack']],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Support'], [0, 3, 'Attack'], [0, 4, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Attack'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Attack'],
#   [2, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support'],
#   [0, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [[1, 0, 'Support'],
#   [2, 1, 'Support'],
#   [2, 3, 'Support'],
#   [3, 4, 'Support'],
#   [5, 'Claim'],
#   [6, 'Claim'],
#   [6, 7, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [1, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[6, 0, 'Attack'],
#   [0, 1, 'Attack'],
#   [6, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Attack'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [1, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [7, 6, 'Support'],
#   [0, 7, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [],
#  [],
#  [[2, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [5, 4, 'Support'],
#   [1, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Attack'], [1, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Attack'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'],
#   [1, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [5, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Attack'],
#   [3, 2, 'Support'],
#   [0, 3, 'Attack'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [6, 7, 'Support']],
#  [[2, 1, 'Support'],
#   [0, 2, 'Support'],
#   [4, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [0, 8, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 2, 'Support'],
#   [1, 3, 'Support'],
#   [1, 4, 'Support'],
#   [1, 5, 'Support'],
#   [1, 6, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[1, 2, 'Attack']],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [2, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [3, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [5, 6, 'Support'],
#   [3, 7, 'Support']],
#  [[5, 0, 'Support'],
#   [2, 1, 'Support'],
#   [3, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Attack'], [0, 3, 'Attack']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Attack']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[4, 0, 'Support'], [4, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[7, 0, 'Support'],
#   [7, 1, 'Support'],
#   [7, 2, 'Support'],
#   [7, 3, 'Support'],
#   [7, 4, 'Support'],
#   [7, 5, 'Support'],
#   [7, 6, 'Support']],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Attack'], [3, 4, 'Attack']],
#  [[1, 0, 'Support'], [1, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Attack'], [2, 3, 'Support'], [0, 4, 'Attack']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[0, 1, 'Support'], [3, 2, 'Support'], [0, 3, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[3, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'], [3, 1, 'Support'], [3, 2, 'Support'], [4, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [3, 2, 'Support'], [4, 3, 'Support'], [4, 5, 'Support']],
#  [[9, 0, 'Support'],
#   [9, 1, 'Support'],
#   [9, 2, 'Support'],
#   [9, 3, 'Support'],
#   [9, 4, 'Support'],
#   [9, 5, 'Support'],
#   [9, 6, 'Support'],
#   [9, 7, 'Support'],
#   [9, 8, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support'],
#   [3, 6, 'Support'],
#   [3, 7, 'Support']],
#  [],
#  [],
#  [],
#  [[5, 0, 'Support'],
#   [5, 1, 'Support'],
#   [5, 2, 'Support'],
#   [5, 3, 'Support'],
#   [5, 4, 'Support']],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [[0, 1, 'Attack']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [4, 2, 'Support'], [4, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support'],
#   [0, 6, 'Support'],
#   [0, 7, 'Support'],
#   [7, 8, 'Support'],
#   [0, 9, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [2, 3, 'Support'],
#   [2, 4, 'Support'],
#   [0, 5, 'Support'],
#   [5, 6, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[3, 0, 'Support'], [2, 1, 'Support'], [3, 2, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support'], [0, 4, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [1, 3, 'Support'], [3, 4, 'Support']],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support'], [0, 4, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [1, 2, 'Support']],
#  [[0, 1, 'Support']],
#  [],
#  [],
#  [],
#  [[1, 0, 'Support'], [1, 2, 'Support'], [1, 3, 'Support']],
#  [[6, 0, 'Support'],
#   [6, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [1, 3, 'Attack'],
#   [6, 4, 'Support'],
#   [6, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  [[0, 1, 'Support'], [1, 2, 'Support'], [0, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [0, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Support'],
#   [0, 2, 'Support'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [0, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[2, 1, 'Support'], [0, 2, 'Support'], [2, 3, 'Support']],
#  [],
#  [],
#  [],
#  [[4, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [4, 3, 'Support'],
#   [6, 5, 'Support'],
#   [7, 6, 'Support'],
#   [4, 7, 'Support']],
#  [[0, 1, 'Support'],
#   [1, 2, 'Support'],
#   [4, 3, 'Support'],
#   [0, 4, 'Support'],
#   [4, 5, 'Support'],
#   [0, 6, 'Support']],
#  [[3, 0, 'Support'],
#   [3, 1, 'Support'],
#   [3, 2, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [],
#  [],
#  [],
#  [[0, 1, 'Support'],
#   [1, 2, 'Attack'],
#   [0, 3, 'Support'],
#   [5, 4, 'Support'],
#   [0, 5, 'Support']],
#  [[0, 1, 'Attack'],
#   [1, 2, 'Attack'],
#   [0, 3, 'Support'],
#   [3, 4, 'Support'],
#   [3, 5, 'Support']],
#  [[1, 2, 'Attack']],
#  [],
#  [],
#  [[2, 0, 'Support'], [2, 1, 'Support']],
#  [[0, 1, 'Support'], [0, 2, 'Support']],
#  []]

# %%
def get_ar_pairs(grounds):

    grounds_l = []
    
    for sublist in grounds:
        l_tmp = []
        for l in sublist:
            try:
                l_tmp.append(l[2])
            except:
                l_tmp.append("Support")
            
        grounds_l.append(l_tmp)

    return grounds_l

# %%
grounds = get_ar_pairs(grounds)
preds = get_ar_pairs(preds)

# %%
for i,(x,y) in enumerate(zip(grounds, preds)):
    if len(x) != len(y):
        print(i,x,y)
# Out:
# 23 ['Support', 'Support', 'Attack', 'Support', 'Support'] ['Support', 'Support', 'Attack', 'Attack', 'Support', 'Support']
# 24 ['Support', 'Support', 'Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support', 'Support']
# 60 [] ['Attack']
# 72 [] ['Support']
# 75 ['Support'] ['Attack', 'Attack']
# 91 [] ['Support']
# 106 ['Support', 'Support', 'Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support', 'Support', 'Support', 'Support']
# 107 ['Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support']
# 120 [] ['Attack']
# 160 ['Support', 'Support'] ['Support', 'Support', 'Support']
# 169 ['Support', 'Support'] ['Support']
# 223 ['Support', 'Support', 'Support'] []
# 228 ['Support', 'Support'] ['Support', 'Support', 'Support']
# 241 ['Support', 'Support', 'Support'] ['Support', 'Support']
# 247 ['Support', 'Support', 'Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support', 'Support']
# 259 ['Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support', 'Support']
# 286 ['Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support']
# 289 [] ['Support']
# 315 ['Support', 'Support', 'Support'] ['Support', 'Attack', 'Support', 'Attack']
# 344 ['Support', 'Support', 'Support', 'Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support', 'Support', 'Support']
# 393 [] ['Support', 'Support']
# 394 ['Support', 'Support', 'Support', 'Support', 'Support'] ['Support', 'Support', 'Support', 'Support']
# 433 [] ['Attack']

# %%
def opposite(relation_type):
    
    if relation_type == "Support":
        return "Attack"
    else:
        return "Support"

# %%
def harmonize_preds(grounds, preds):

    l1, l2 = len(preds), len(grounds)
    if l1 < l2:
        diff = l2 - l1
        preds = preds + [opposite(x) for x in grounds[l1:]]
    else:
        preds = preds[:l2]
        
    return preds

# %%
for i,(x,y) in enumerate(zip(grounds, preds)):
    
    if len(x) != len(y):
        
        preds[i] = harmonize_preds(x, y)

# %%
LTC_preds = [item for row in preds for item in row]
LTC_grounds = [item for row in grounds for item in row]

# %%
# sanity check: 
len(LTC_preds) == len(LTC_grounds)
# Out:
# True

# %%
print(classification_report(LTC_grounds, LTC_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Attack      0.617     0.630     0.624        46
#      Support      0.975     0.973     0.974       678
#
#     accuracy                          0.952       724
#    macro avg      0.796     0.802     0.799       724
# weighted avg      0.952     0.952     0.952       724
